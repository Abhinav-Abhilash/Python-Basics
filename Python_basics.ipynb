# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav-Abhilash/Python-Basics/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 - My Digital Identity
name = "Abhinav Abhilash KV"
reg_no = "26JSOFT002"
department = "BCA Full Stack AI Development"
semester = 1
skills = "HTML, PYTHON, C++, SQL"
hobbies = "Minecraft Server Hosting, UI/UX Design"
dream_company = "Google"
github = "https://github.com/Abhinav-Abhilash"
linkedin = "https://www.linkedin.com/in/abhinavabhilash/"
career_goal = "Full Stack Developer & UI/UX Designer"

print("=" * 40)
print("        MY DIGITAL IDENTITY")
print("=" * 40)
print(f"Name         : {name}")
print(f"Reg Number   : {reg_no}")
print(f"Department   : {department}")
print(f"Semester     : {semester}")
print(f"Skills       : {skills}")
print(f"Hobbies      : {hobbies}")
print(f"Dream Company: {dream_company}")
print(f"GitHub       : {github}")
print(f"LinkedIn     : {linkedin}")
print(f"Career Goal  : {career_goal}")
print("=" * 40)

# %%
# Task 2 - Student Profile Manager
name = input("Name: ")
age = int(input("Age: "))
department = input("Department: ")
cgpa = float(input("CGPA: "))
blood_group = input("Blood Group: ")
email = input("Email: ")
phone = input("Phone: ")

print("\n" + "=" * 40)
print("         STUDENT PROFILE")
print("=" * 40)
print(f"Name        : {name}")
print(f"Age         : {age}")
print(f"Department  : {department}")
print(f"CGPA        : {cgpa}")
print(f"Blood Group : {blood_group}")
print(f"Email       : {email}")
print(f"Phone       : {phone}")
print("=" * 40)

# %%
# Task 3 - Resume Generator
name = input("Full Name: ")
education = input("Education: ")
skills = input("Skills (comma separated): ")
projects = input("Projects (comma separated): ")
languages = input("Languages known: ")

print("\n" + "=" * 45)
print(f"{name.upper():^45}")
print("=" * 45)
print("\nEDUCATION")
print("-" * 45)
print(education)
print("\nSKILLS")
print("-" * 45)
for s in skills.split(","):
    print(f"  • {s.strip()}")
print("\nPROJECTS")
print("-" * 45)
for p in projects.split(","):
    print(f"  • {p.strip()}")
print("\nLANGUAGES")
print("-" * 45)
print(languages)
print("=" * 45)

# %%
# Task 4 - Portfolio README Generator
name = input("Name: ")
role = input("Role: ")
skills = input("Skills: ")
project = input("Project Name: ")
github = input("GitHub Link: ")
linkedin = input("LinkedIn Link: ")

print("\n" + "=" * 45)
print("             README.md CONTENT")
print("=" * 45)
print(f"# {name}")
print("\n## Overview")
print(f"I am a {role} focused on building clean, efficient, and scalable applications.")
print(f"My technical background includes working extensively with {skills}.")
print(f"Currently, I am developing {project}, where I am exploring new ways to solve problems through code.")
print("\n## Let's Connect")
print("I am always open to discussing tech, projects, or new opportunities.")
print(f"- LinkedIn: {linkedin}")
print(f"- GitHub: {github}")
print("=" * 45)

# %%
# Task 5 - Smart Bio Generator
name = input("Name: ")
role = input("Role: ")
skills = input("Skills: ")
interest = input("Main Interest: ")

print("\n" + "=" * 45)
print("              GENERATED BIOS")
print("=" * 45)

print("\nLinkedIn:")
print(f"I am a {role} with a strong foundation in {skills}. I enjoy tackling complex technical challenges and am currently focusing my learning and development on {interest}. I am always looking to connect with other developers and professionals in the industry.")

print("\nGitHub:")
print(f"{role} specializing in {skills}. Actively building projects related to {interest} and open source.")

print("\nTwitter:")
print(f"{role} working with {skills}. Sharing my journey in software development and exploring {interest}.")

print("\nWebsite:")
print(f"Hello, I'm {name}. I am a {role} who builds digital experiences using {skills}. My current work and research are heavily focused on {interest}. Take a look around my portfolio to see my latest projects.")
print("=" * 45)
